# %%
using DynamicPolynomials
@polyvar x y
p = 2*x^4 + 2*x^3*y - x^2*y^2 + 5*y^4
# Out:
# 2x⁴ + 2x³y - x²y² + 5y⁴

# %%
using SumOfSquares
using MosekTools
solver = optimizer_with_attributes(Mosek.Optimizer, MOI.Silent() => true)
model = SOSModel(solver)
con_ref = @constraint(model, p >= 0)
optimize!(model)
primal_status(model)
# Out:
# FEASIBLE_POINT::ResultStatusCode = 1

# %%
q = gram_matrix(con_ref)
# Out:
# GramMatrix{Float64, MonomialBasis{Monomial{true}, MonomialVector{true}}, Float64, SymMatrix{Float64}}([1.999999999955124 0.9999999999551256 -1.5283258634975887; 0.9999999999551256 2.0566517270849265 -2.8320934409251583e-15; -1.5283258634975887 -2.8320934409251583e-15 4.999999999820499], MonomialBasis{Monomial{true}, MonomialVector{true}}(Monomial{true}[x², xy, y²]))

# %%
sosdec = SOSDecomposition(q)
# Out:
# (-0.9691566727831898*x^2 - 0.267100704421015*x*y + 2.1620536581677126*y^2)^2 + (-0.7981501821144377*x^2 - 1.323277398711559*x*y - 0.521254824533208*y^2)^2 + (0.6509159933091443*x^2 - 0.48398953174825377*x*y + 0.23198574724531326*y^2)^2

# %%
p = 4*x^4*y^6 + x^2 - x*y^2 + y^2
# Out:
# 4x⁴y⁶ - xy² + x² + y²

# %%
model = Model(solver)
con_ref = @constraint(model, p in SOSCone())
optimize!(model)
primal_status(model)
# Out:
# FEASIBLE_POINT::ResultStatusCode = 1

# %%
sos_decomposition(con_ref)
# Out:
# (-1.9869183795461085*x^2*y^3 + 8.575990219994279e-22*x*y^2 - 0.0748764789355902*x*y - 2.1812817676697623e-19*x + 0.4616124642985459*y)^2 + (-4.5470312066815413e-17*x^2*y^3 + 1.1111666842293808*x*y^2 - 2.7056200379496144e-17*x*y - 0.7522742932006998*x - 2.537346977189281e-16*y)^2 + (0.20249996147797136*x^2*y^3 - 1.341919812930188e-16*x*y^2 - 0.9515532506165079*x*y - 1.9033063951781355e-17*x + 0.7172725261983873*y)^2 + (-2.119847357832129e-17*x^2*y^3 + 0.4460500502610863*x*y^2 - 1.0575015959282456e-16*x*y + 0.6588500495479893*x - 1.1829124584551768e-16*y)^2 + (-0.10558938411851364*x^2*y^3 - 1.1252622012558354e-16*x*y^2 - 0.41591344402547487*x*y - 3.240311952995594e-17*x - 0.5219521586938871*y)^2
